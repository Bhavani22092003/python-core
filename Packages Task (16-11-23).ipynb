# %% [markdown]
# ## package

# %% [markdown]
# > In Python, a package is a way of organizing related modules into a single directory hierarchy. A package is a collection of Python module files (.py files) and a special file named __init__.py. The __init__.py file can be empty, but it indicates that the directory should be considered a Python package.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### creating a function as foo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Calling module1  from main package(Innomatics)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Creating sub packages in main package

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### In the above ,batch261,batch264,and batch265 are the sub packages of main package(innomatics)

# %% [markdown]
# ### In batch261 we have one module(maths)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Functions in batch261 -->maths module

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Importing that functions in another file which is saved in different drive location.

# %% [markdown]
# > first we have to import os and sys
# >> Next,we have to insert drive path to the system path
# >>> Then we have to import our main package and subpackages and module in the sub packages

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Importing maths module from a batch261 subpackage.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Functions in functions(module) in batch264(subpackage)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Importing functions module  from batch264 subpackage

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Functions in details module

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Importing details module from subpackages of batch265

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Script functions

# %% [markdown]
# > checking wheather module are running as script or not

# %% [markdown]
# ![image.png](attachment:image.png)
